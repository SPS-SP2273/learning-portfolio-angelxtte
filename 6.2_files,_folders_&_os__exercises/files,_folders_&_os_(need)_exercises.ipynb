# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %%
import os
import glob
import shutil

# %% [markdown]
# # Exercise 1

# %%
dates = {
'jan': '01', 'feb': '02', 'mar': '03',
'apr': '04', 'may': '05', 'jun': '06',
'jul': '07', 'aug': '08', 'sep': '09',
'oct': '10', 'nov': '11', 'dec': '12'
}

name = "oct-08_singapore.txt"
if name[0:3] in dates:
    name = f"{dates[name[0:3]]}{name[3:]}"
print(name)
# Out:
# 10-08_singapore.txt

# %% [markdown]
# # Exercise 2

# %%
def rename_my_file(old_file_name):
    dates = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }
    if old_file_name[0:3] in dates:
        new_file_name = f"{dates[old_file_name[0:3]]}{old_file_name[3:]}"
        return new_file_name

rename_my_file("oct-08_singapore.txt")
# Out:
# '10-08_singapore.txt'

# %% [markdown]
# # Exercise 3

# %%
names = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for name in names:
    print(f"{name} ----> {rename_my_file(name)}")
# Out:
# oct-08_singapore.txt ----> 10-08_singapore.txt
# jul-10_cairo.txt ----> 07-10_cairo.txt
# may-15_dhaka.txt ----> 05-15_dhaka.txt
# may-13_cairo.txt ----> 05-13_cairo.txt
# oct-21_cairo.txt ----> 10-21_cairo.txt
# jan-10_singapore.txt ----> 01-10_singapore.txt
# jun-20_tokyo.txt ----> 06-20_tokyo.txt
# aug-06_jakarta.txt ----> 08-06_jakarta.txt
# dec-21_karachi.txt ----> 12-21_karachi.txt
# jan-01_tokyo.txt ----> 01-01_tokyo.txt

# %% [markdown]
# # Exercise 4

# %%
for i in glob.glob("os-collaboration-exercise-data\\*.txt"):
    folder = os.path.split(i)
    try:
        os.rename(i, os.path.join(folder[0], rename_my_file(folder[1])))
        print(f"{folder[1]} ----> {rename_my_file(folder[1])}")
    except:
        print(f"{folder[1]} already exists!")
# Out:
# apr-01_melbourne.txt ----> 04-01_melbourne.txt
# apr-01_shanghai.txt ----> 04-01_shanghai.txt
# apr-01_singapore.txt ----> 04-01_singapore.txt
# apr-02_cairo.txt ----> 04-02_cairo.txt
# apr-02_jakarta.txt ----> 04-02_jakarta.txt
# apr-02_karachi.txt ----> 04-02_karachi.txt
# apr-02_shanghai.txt ----> 04-02_shanghai.txt
# apr-03_manila.txt ----> 04-03_manila.txt
# apr-03_osaka.txt ----> 04-03_osaka.txt
# apr-03_singapore.txt ----> 04-03_singapore.txt
# apr-03_tokyo.txt ----> 04-03_tokyo.txt
# apr-04_manila.txt ----> 04-04_manila.txt
# apr-04_melbourne.txt ----> 04-04_melbourne.txt
# apr-04_shanghai.txt ----> 04-04_shanghai.txt
# apr-04_singapore.txt ----> 04-04_singapore.txt
# apr-05_karachi.txt ----> 04-05_karachi.txt
# apr-05_melbourne.txt ----> 04-05_melbourne.txt
# apr-05_shanghai.txt ----> 04-05_shanghai.txt
# apr-05_singapore.txt ----> 04-05_singapore.txt
# apr-06_cairo.txt ----> 04-06_cairo.txt
# apr-06_jakarta.txt ----> 04-06_jakarta.txt
# ...

# %% [markdown]
# # Exercise 5

# %%
folders = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
for i in folders: 
    path = os.path.join("os-collaboration-exercise-data", i)
    os.mkdir(path)
    print(f"Folder called {i} has been made!")
# Out:
# Folder called Cairo has been made!
# Folder called Dhaka has been made!
# Folder called Jakarta has been made!
# Folder called Karachi has been made!
# Folder called Manila has been made!
# Folder called Melbourne has been made!
# Folder called Osaka has been made!
# Folder called Shanghai has been made!
# Folder called Singapore has been made!
# Folder called Tokyo has been made!

# %% [markdown]
# # Exercise 6

# %%
for i in glob.glob(r"os-collaboration-exercise-data\*cairo*"):
    if "Cairo" not in i: # Exclude File
        shutil.copy(i, r"os-collaboration-exercise-data\Cairo")
        print(f"{os.path.split(i)[1]} has been copied to the Folder called Cairo")
# Out:
# 01-02_cairo.txt has been copied to the Folder called Cairo
# 01-03_cairo.txt has been copied to the Folder called Cairo
# 01-04_cairo.txt has been copied to the Folder called Cairo
# 01-05_cairo.txt has been copied to the Folder called Cairo
# 01-07_cairo.txt has been copied to the Folder called Cairo
# 01-08_cairo.txt has been copied to the Folder called Cairo
# 01-09_cairo.txt has been copied to the Folder called Cairo
# 01-11_cairo.txt has been copied to the Folder called Cairo
# 01-12_cairo.txt has been copied to the Folder called Cairo
# 01-13_cairo.txt has been copied to the Folder called Cairo
# 01-15_cairo.txt has been copied to the Folder called Cairo
# 01-16_cairo.txt has been copied to the Folder called Cairo
# 01-19_cairo.txt has been copied to the Folder called Cairo
# 01-20_cairo.txt has been copied to the Folder called Cairo
# 01-21_cairo.txt has been copied to the Folder called Cairo
# 01-23_cairo.txt has been copied to the Folder called Cairo
# ...

# %% [markdown]
# # Exercise 7

# %%
folders = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
for i in glob.glob(r"os-collaboration-exercise-data\*"):
    for country in folders:
        if country.lower() in i:
            if not os.path.exists(rf"os-collaboration-exercise-data\{country}\{os.path.split(i)[1]}"):
                shutil.move(i, rf"os-collaboration-exercise-data\{country}")
                print(f"{os.path.split(i)[1]} has been copied to the Folder called {country}")
            else:
                os.remove(i)
                print(f"Duplicate file! {os.path.split(i)[1]} has been removed from the main folder!")
# Out:
# 01-01_manila.txt has been copied to the Folder called Manila
# 01-01_osaka.txt has been copied to the Folder called Osaka
# Duplicate file! 01-02_cairo.txt has been removed from the main folder!
# 01-02_karachi.txt has been copied to the Folder called Karachi
# 01-02_manila.txt has been copied to the Folder called Manila
# Duplicate file! 01-03_cairo.txt has been removed from the main folder!
# 01-03_jakarta.txt has been copied to the Folder called Jakarta
# 01-03_karachi.txt has been copied to the Folder called Karachi
# 01-03_shanghai.txt has been copied to the Folder called Shanghai
# Duplicate file! 01-04_cairo.txt has been removed from the main folder!
# 01-04_jakarta.txt has been copied to the Folder called Jakarta
# 01-04_karachi.txt has been copied to the Folder called Karachi
# 01-04_manila.txt has been copied to the Folder called Manila
# Duplicate file! 01-05_cairo.txt has been removed from the main folder!
# ...
